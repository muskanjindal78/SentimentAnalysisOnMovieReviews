# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/sentiment-prediction-on-movie-reviews/movies.csv
# /kaggle/input/sentiment-prediction-on-movie-reviews/sample.csv
# /kaggle/input/sentiment-prediction-on-movie-reviews/train.csv
# /kaggle/input/sentiment-prediction-on-movie-reviews/test.csv

# %%
sample_data = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/sample.csv")
movies_data = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/movies.csv")
train_data = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/train.csv")
test_data = pd.read_csv("/kaggle/input/sentiment-prediction-on-movie-reviews/test.csv")

# %%
sample_data.head()
# Out:
#    id sentiment
# 0   0  NEGATIVE
# 1   1  NEGATIVE
# 2   2  NEGATIVE
# 3   3  NEGATIVE
# 4   4  NEGATIVE

# %%
movies_data.head()
# Out:
#                                              movieid  \
# 0                  han_solo_heroic_myth_wonder_woman
# 1              voyage_tyler_durden_han_solo_stardust
# 2  norman_bates_ferris_bueller_hermione_granger_v...
# 3                           elegant_hermione_granger
# 4                             adventure_rocky_balboa
#
#                                                title  audienceScore rating  \
# 0                  Han Solo Heroic Myth Wonder Woman           50.0    NaN
# 1              Voyage Tyler Durden Han Solo Stardust            NaN    NaN
# 2  Norman Bates Ferris Bueller Hermione Granger V...           43.0    NaN
# 3                           Elegant Hermione Granger           60.0    NaN
# 4                             Adventure Rocky Balboa           70.0    NaN
#
#   ratingContents releaseDateTheaters releaseDateStreaming  runtimeMinutes  \
# 0            NaN                 NaN           2018-08-25            75.0
# 1            NaN                 NaN           2020-02-11           114.0
# 2            NaN                 NaN                  NaN           120.0
# 3            NaN                 NaN           2020-10-23            90.0
# 4            NaN                 NaN           2017-03-27            80.0
#
#                            genre originalLanguage        director boxOffice  \
# 0         Comedy, Horror, Sci-fi          English  Claude Nicolet       NaN
# 1                          Drama          English    Nathan Haack       NaN
# 2                          Drama           Korean   Theresa Smith       NaN
# 3     Action, Mystery & thriller          English    Donald Lewis       NaN
# 4  Fantasy, Adventure, Animation          English    Howard Simms       NaN
#
#   distributor soundType
# 0         NaN       NaN
# 1         NaN       NaN
# 2         NaN       NaN
# 3         NaN       NaN
# 4         NaN       NaN

# %%
train_data.head()
# Out:
#                                              movieid         reviewerName  \
# 0                                   marvelous_pirate       Benjamin Henry
# 1          tony_montana_frodo_baggins_v_rocky_balboa        Felicia Lopez
# 2  darth_vader_katniss_everdeen_sorcerer_donnie_d...  Mr. Charles Burgess
# 3                                 lara_croft_glimmer         Ryan Barrett
# 4  jason_bourne_surreal_the_terminator_indiana_jones     Alexander Glover
#
#    isFrequentReviewer                                         reviewText  \
# 0               False  Henry Selick’s first movie since 2009’s Corali...
# 1               False  With a cast that reads like the Vogue Oscar pa...
# 2                True  Creed II does not give us anything but another...
# 3               False  I know what you're thinking, but this is no Li...
# 4               False  Director Fernando Meirelles tells the story wi...
#
#   sentiment
# 0  POSITIVE
# 1  NEGATIVE
# 2  POSITIVE
# 3  POSITIVE
# 4  POSITIVE

# %%
test_data.head()
# Out:
#                                movieid     reviewerName  isTopCritic  \
# 0            legend_marty_mcfly_oracle         John Kim        False
# 1  terminator_katniss_everdeen_glimmer     Brian Chaney        False
# 2          james_bond_labyrinth_gollum  Danielle Parker        False
# 3            v_quest_han_solo_wondrous    Brittany Lane        False
# 4        enigma_hulk_surreal_starlight    Justin Willis        False
#
#                                           reviewText
# 0  Green slowly cranks up the dread with style an...
# 1  Philip Noyce's direction is elegant and unforc...
# 2  It wouldn't do to say what path Maria ultimate...
# 3  Pig is not exactly the arthouse John Wick that...
# 4  An imaginative no-budget musical of sorts abou...

# %%
train_data.shape
# Out:
# (162758, 5)

# %%
train_data.merge(movies_data)
# Out:
#                                                  movieid     reviewerName  \
# 0                                       marvelous_pirate   Benjamin Henry
# 1                                       marvelous_pirate    Sharon Foster
# 2                                       marvelous_pirate     Melinda Dunn
# 3                                       marvelous_pirate  Mr. Wayne Smith
# 4                                       marvelous_pirate    Connor Nelson
# ...                                                  ...              ...
# 525272  frodo_baggins_norman_bates_ellen_ripley_astonish   Janice Pearson
# 525273      elegant_starlight_labyrinth_katniss_everdeen    Frank Farrell
# 525274             don_vito_corleone_neo_hannibal_lecter      Juan Taylor
# 525275        dorothy_gale_luke_skywalker_luke_skywalker  Robert Cardenas
# 525276                         forrest_gump_fantasy_epic   Daniel Pacheco
#
#         isFrequentReviewer                                         reviewText  \
# 0                    False  Henry Selick’s first movie since 2009’s Corali...
# 1                    False  &#91;T&#93;he haphazard way this story is asse...
# 2                    False  The stop-motion artistry of Wendell &amp; Wild...
# 3                    False  Wendell &amp; Wild is narratively overstuffed ...
# 4                    False  For being about the Netherworlds&#44; it&#8217...
# ...                    ...                                                ...
# 525272               False  The broad shape of the ending is predictable; ...
# 525273               False  A formula designed for adolescent and young ad...
# 525274               False  All these years, I've kept a soft spot in my h...
# 525275               False  Powerful documentary about the struggle of Wes...
# 525276                True  Rock's wildest years - both the man and the mu...
#
#        sentiment                                             title  \
# 0       POSITIVE                                  Marvelous Pirate
# 1       NEGATIVE                                  Marvelous Pirate
# 2       POSITIVE                                  Marvelous Pirate
# 3       NEGATIVE                                  Marvelous Pirate
# 4       POSITIVE                                  Marvelous Pirate
# ...          ...                                               ...
# 525272  NEGATIVE  Frodo Baggins Norman Bates Ellen Ripley Astonish
# 525273  POSITIVE      Elegant Starlight Labyrinth Katniss Everdeen
# 525274  NEGATIVE             Don Vito Corleone Neo Hannibal Lecter
# 525275  POSITIVE        Dorothy Gale Luke Skywalker Luke Skywalker
# 525276  POSITIVE                         Forrest Gump Fantasy Epic
#
#         audienceScore rating  \
# 0                65.0  PG-13
# 1                65.0  PG-13
# 2                65.0  PG-13
# 3                65.0  PG-13
# 4                65.0  PG-13
# ...               ...    ...
# 525272           81.0    NaN
# 525273           75.0    NaN
# 525274           55.0    NaN
# 525275           75.0    NaN
# 525276           45.0    NaN
#
#                                            ratingContents releaseDateTheaters  \
# 0       ['Violence', 'Brief Strong Language', 'Substan...          2022-10-21
# 1       ['Violence', 'Brief Strong Language', 'Substan...          2022-10-21
# 2       ['Violence', 'Brief Strong Language', 'Substan...          2022-10-21
# 3       ['Violence', 'Brief Strong Language', 'Substan...          2022-10-21
# 4       ['Violence', 'Brief Strong Language', 'Substan...          2022-10-21
# ...                                                   ...                 ...
# 525272                                                NaN                 NaN
# 525273                                                NaN          2018-04-13
# 525274                                                NaN          1987-02-20
# 525275                                                NaN          2008-02-29
# 525276                                                NaN          2017-04-07
#
#        releaseDateStreaming  runtimeMinutes  \
# 0                2022-10-28           105.0
# 1                2022-10-28           105.0
# 2                2022-10-28           105.0
# 3                2022-10-28           105.0
# 4                2022-10-28           105.0
# ...                     ...             ...
# 525272           2019-03-19           111.0
# 525273           2018-09-18            93.0
# 525274           2009-04-14            96.0
# 525275           2009-07-14            89.0
# 525276           2017-04-07            95.0
#
#                                         genre originalLanguage  \
# 0       Comedy, Animation, Adventure, Fantasy          English
# 1       Comedy, Animation, Adventure, Fantasy          English
# 2       Comedy, Animation, Adventure, Fantasy          English
# 3       Comedy, Animation, Adventure, Fantasy          English
# 4       Comedy, Animation, Adventure, Fantasy          English
# ...                                       ...              ...
# 525272                           Crime, Drama         Filipino
# 525273             Horror, Mystery & thriller           Korean
# 525274                                 Comedy          English
# 525275                            Documentary          English
# 525276                     Documentary, Music          English
#
#                 director boxOffice        distributor soundType
# 0           Bennie Basso       NaN            Netflix       NaN
# 1           Bennie Basso       NaN            Netflix       NaN
# 2           Bennie Basso       NaN            Netflix       NaN
# 3           Bennie Basso       NaN            Netflix       NaN
# 4           Bennie Basso       NaN            Netflix       NaN
# ...                  ...       ...                ...       ...
# 525272      Sara Maggard       NaN                NaN       NaN
# 525273     Frances Gagne   $111.2K        Well Go USA       NaN
# 525274  Claudia Bernhard   $799.4K                NaN       NaN
# 525275      James Fanney       NaN                NaN       NaN
# 525276   Tawanda Ballard    $14.0K  Magnolia Pictures       NaN
#
# [525277 rows x 18 columns]

# %%
sample_data.dtypes
# Out:
# id            int64
# sentiment    object
# dtype: object

# %%
train_data.dtypes
# Out:
# movieid               object
# reviewerName          object
# isFrequentReviewer      bool
# reviewText            object
# sentiment             object
# dtype: object

# %%
movies_data.dtypes
# Out:
# movieid                  object
# title                    object
# audienceScore           float64
# rating                   object
# ratingContents           object
# releaseDateTheaters      object
# releaseDateStreaming     object
# runtimeMinutes          float64
# genre                    object
# originalLanguage         object
# director                 object
# boxOffice                object
# distributor              object
# soundType                object
# dtype: object

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.dummy import DummyClassifier

xTrain = train_data['reviewText']
yTrain = train_data['sentiment']

dummy = DummyClassifier(strategy="most_frequent")
dummy.fit(xTrain, yTrain)

pred = dummy.predict(test_data['reviewText'])
pred = pd.DataFrame(pred)
pred.columns = ['sentiment']
pred.index.name = 'id'
pred.to_csv('submission.csv')
